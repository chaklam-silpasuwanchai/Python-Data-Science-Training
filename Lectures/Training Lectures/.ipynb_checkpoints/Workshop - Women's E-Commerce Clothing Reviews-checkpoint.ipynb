# %% [markdown]
# # Data Science Training
#
# ## Workshop - Women's E-Commerce Clothing Reviews

# %% [markdown]
# ### Introduction
#
# In these times of quarantine, online shopping have shown to be one of the greatest stress-busters for women!
# While all of us are on our journeys to becoming shopaholics or broke, let us analyze the importance of CUSTOMER REVIEWS while shopping online.
#
# As per facts, 61% of customers read online reviews before making a purchase decision, and they are now essential for e-commerce sites. Also, according to Reevoo, reviews produce an average 18% uplift in sales. Hence USER REVIEWS are proven sales drivers, and something the majority of customers will definitely want to see before deciding to make a purchase.
#
# #### Overall goal:
# You are a data scienctist and would like you to perform a Topic Modeling (LDA). Topic modeling is a type of statistical modeling for discovering the abstract “topics” that occur in a collection of documents. Latent Dirichlet Allocation (LDA) is an example of topic model and is used to classify text in a document to a particular topic. It builds a topic per document model and words per topic model, modeled as Dirichlet distributions.
#
# #### Section 01: Exploratory Data Analysis
# * Are there any null values or outliers? How will you wrangle/handle them?
# * Are there any variables that warrant transformations?
# * Are there any useful variables that you can engineer with the given data?
# * Do you notice any patterns or anomalies in the data? Can you plot them?
#
# #### Section 02: Data Analysis
# * Is it a regression/ classification problem?
# * Is it a supervised/ unsupervised problem?
# * Which model parameters should we take care of?

# %% [markdown]
# ### Importing data and libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import string
import seaborn as sns
import time

# nltk
import nltk
from nltk.corpus import stopwords # python3 -m nltk.downloader stopwords
stoplist= stopwords.words('english')
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer= WordNetLemmatizer()
from nltk.corpus import wordnet
from sklearn.feature_extraction.text import CountVectorizer

import warnings
warnings.filterwarnings('ignore')

# Enable logging
import logging
logging.basicConfig(level= logging.INFO)

# %% [markdown]
# #### Section 01: Exploratory Data Analysis

# %% [markdown]
# Import the data from data folder, the file is called Womens Clothing E-Commerce Reviews.csv

# %%
df= pd.read_csv("data/Womens Clothing E-Commerce Reviews.csv", index_col=0)
df.columns= df.columns.str.replace(" ", "_")
print(df.shape)
# Out:
# (23486, 10)

# %% [markdown]
# Let's check the column names

# %%
# your code here
# Out:
# Index(['Clothing_ID', 'Age', 'Title', 'Review_Text', 'Rating',
#        'Recommended_IND', 'Positive_Feedback_Count', 'Division_Name',
#        'Department_Name', 'Class_Name'],
#       dtype='object')

# %% [markdown]
# How do the first 5 rows of data look?

# %%
# your code here
# Out:
#    Clothing_ID  Age                    Title  \
# 0          767   33                      NaN
# 1         1080   34                      NaN
# 2         1077   60  Some major design flaws
# 3         1049   50         My favorite buy!
# 4          847   47         Flattering shirt
#
#                                          Review_Text  Rating  Recommended_IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive_Feedback_Count   Division_Name Department_Name Class_Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %% [markdown]
# How about the last 5 rows of data?

# %%
# your code here
# Out:
#        Clothing_ID  Age                                              Title  \
# 23481         1104   34                     Great dress for many occasions
# 23482          862   48                         Wish it was made of cotton
# 23483         1104   31                              Cute, but see through
# 23484         1084   28  Very cute dress, perfect for summer parties an...
# 23485         1104   52                    Please make more like this one!
#
#                                              Review_Text  Rating  \
# 23481  I was very happy to snag this dress at such a ...       5
# 23482  It reminds me of maternity clothes. soft, stre...       3
# 23483  This fit well, but the top was very see throug...       3
# 23484  I bought this dress for a wedding i have this ...       3
# 23485  This dress in a lovely platinum is feminine an...       5
#
#        Recommended_IND  Positive_Feedback_Count   Division_Name  \
# 23481                1                        0  General Petite
# 23482                1                        0  General Petite
# 23483                0                        1  General Petite
# 23484                1                        2         General
# 23485                1                       22  General Petite
#
#       Department_Name Class_Name
# 23481         Dresses    Dresses
# 23482            Tops      Knits
# 23483         Dresses    Dresses
# 23484         Dresses    Dresses
# 23485         Dresses    Dresses

# %% [markdown]
# Let's describe our data

# %%
# your code here
# Out:
#         Clothing_ID           Age        Rating  Recommended_IND  \
# count  23486.000000  23486.000000  23486.000000     23486.000000
# mean     918.118709     43.198544      4.196032         0.822362
# std      203.298980     12.279544      1.110031         0.382216
# min        0.000000     18.000000      1.000000         0.000000
# 25%      861.000000     34.000000      4.000000         1.000000
# 50%      936.000000     41.000000      5.000000         1.000000
# 75%     1078.000000     52.000000      5.000000         1.000000
# max     1205.000000     99.000000      5.000000         1.000000
#
#        Positive_Feedback_Count
# count             23486.000000
# mean                  2.535936
# std                   5.702202
# min                   0.000000
# 25%                   0.000000
# 50%                   1.000000
# 75%                   3.000000
# max                 122.000000

# %%
# your code here
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23486 entries, 0 to 23485
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Clothing_ID              23486 non-null  int64
#  1   Age                      23486 non-null  int64
#  2   Title                    19676 non-null  object
#  3   Review_Text              22641 non-null  object
#  4   Rating                   23486 non-null  int64
#  5   Recommended_IND          23486 non-null  int64
#  6   Positive_Feedback_Count  23486 non-null  int64
#  7   Division_Name            23472 non-null  object
#  8   Department_Name          23472 non-null  object
#  9   Class_Name               23472 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# Let's check the missing values

# %%
# Check missing values
# your code here
# Out:
# Missing values in data :
#  Clothing_ID                   0
# Age                           0
# Title                      3810
# Review_Text                 845
# Rating                        0
# Recommended_IND               0
# Positive_Feedback_Count       0
# Division_Name                14
# Department_Name              14
# Class_Name                   14
# dtype: int64

# %% [markdown]
# Since the reviews is our main content, dropping rows where 'Review Text' is null

# %%
# your code here
# Out:
# (22641, 10)

# %% [markdown]
# Let's check the missing values after dropping rows where 'Review Text' is null

# %%
# your code here
# Out:
# Missing values in data :
#  Clothing_ID                   0
# Age                           0
# Title                      2966
# Review_Text                   0
# Rating                        0
# Recommended_IND               0
# Positive_Feedback_Count       0
# Division_Name                13
# Department_Name              13
# Class_Name                   13
# dtype: int64

# %%
# Golden rule: Save up the original dataframe
df_orig= df.copy()
df_orig.shape 

# df= df_orig.copy()
# Out:
# (22641, 10)

# %% [markdown]
# #### Section 02: Data Analysis

# %% [markdown]
# For topic modeling, we will use the infamous LDA (Latent Dirichlet Allocation) algorithm. In LDA, each document can be described by a distribution of topics and each topic can be described by a distribution of words.

# %% [markdown]
# STEP 1: Preprocessing text - Tokenizing sentences, stopwords removal and lemmatization
#
# * Sentence tokenization is the process of splitting text into individual sentences
# * Stop words are available in abundance in any human language. By removing these words, we remove the low-level information from our text in order to give more focus to the important information.
# * Lemmatization usually refers to doing things properly with the use of a vocabulary and morphological analysis of words, normally aiming to remove inflectional endings only and to return the base or dictionary form of a word, which is known as the lemma .

# %%
def get_pos_tag(tag):
    """This function is used to get the part-of-speech(POS) for lemmatization"""
    
    if tag.startswith('N') or tag.startswith('J'):
        return wordnet.NOUN
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN #default case

# %%
# python3 -m nltk.downloader punkt
# python3 -m nltk.downloader averaged_perceptron_tagger
# python3 -m nltk.downloader wordnet
import re
def preprocess(text):
    """ 1. Removes Punctuations
        2. Removes words smaller than 3 letters
        3. Converts into lowercase
        4. Lemmatizes words
        5. Removes Stopwords
    """   
    punctuation= list(string.punctuation)
    doc_tokens= nltk.word_tokenize(text)
    word_tokens= [word.lower() for word in doc_tokens if not (word in punctuation or len(word)<=3)]
    
    # Lemmatize    
    pos_tags=nltk.pos_tag(word_tokens)
#     print(pos_tags)
    doc_words=[wordnet_lemmatizer.lemmatize(word, pos=get_pos_tag(tag)) for word, tag in pos_tags]
    doc_words= [word for word in doc_words if word not in stoplist]
    
    return doc_words
# Out:
# 0    [absolutely, wonderful, silky, sexy, comfortable]
# 1    [love, dress, sooo, pretty, happen, find, stor...
# 2    [high, hope, dress, really, want, work, initia...
# 3    [love, love, love, jumpsuit, flirty, fabulous,...
# 4    [shirt, flatter, adjustable, front, perfect, l...
# Name: Review_Text, dtype: object

# %%
# We are interested in the column "Review_Text"
# your code here

# %% [markdown]
# STEP 2: DATA CLEANING- PROCURE ONLY NOUNS AND ADJECTIVES TO OBTAIN MEANINGFUL TOPICS!

# %%
# Tried multiple parts of speech and obtained best topic results using Nouns and Adjectives!
def get_nouns_adjs(series):
    
    " Topic Modeling using only nouns and adjectives"
    
    pos_tags= nltk.pos_tag(series)
    all_adj_nouns= [word for (word, tag) in pos_tags if (tag=="NN" or tag=="NNS" or tag=="JJ")] 
    return all_adj_nouns

# %%
# your code here hint: use apply

# %% [markdown]
# Step 3: Add bigrams to your corpus using Word2vec model from gensim

# %% [markdown]
# Importing gensim related libraries

# %%
# Importing gensim related libraries
import gensim
from gensim.models.ldamulticore import LdaMulticore
from gensim.corpora import Dictionary
from gensim.models import Phrases
from collections import Counter
from gensim.models import Word2Vec

# %%
docs= list(df_nouns_adj)
phrases = gensim.models.Phrases(docs, min_count=10, threshold=20)
bigram_model = gensim.models.phrases.Phraser(phrases)
# Out:
# INFO:gensim.models.phrases:collecting all words and their counts
# INFO:gensim.models.phrases:PROGRESS: at sentence #0, processed 0 words and 0 word types
# INFO:gensim.models.phrases:PROGRESS: at sentence #10000, processed 174273 words and 96030 word types
# INFO:gensim.models.phrases:PROGRESS: at sentence #20000, processed 349830 words and 162208 word types
# INFO:gensim.models.phrases:collected 177651 token types (unigram + bigrams) from a corpus of 396320 words and 22641 sentences
# INFO:gensim.models.phrases:merged Phrases<177651 vocab, min_count=10, threshold=20, max_vocab_size=40000000>
# INFO:gensim.utils:Phrases lifecycle event {'msg': 'built Phrases<177651 vocab, min_count=10, threshold=20, max_vocab_size=40000000> in 0.97s', 'datetime': '2021-11-05T09:32:23.303883', 'gensim': '4.1.2', 'python': '3.9.7 | packaged by conda-forge | (default, Sep 29 2021, 19:20:46) \n[GCC 9.4.0]', 'platform': 'Linux-4.15.0-159-generic-x86_64-with-glibc2.31', 'event': 'created'}
# INFO:gensim.models.phrases:exporting phrases from Phrases<177651 vocab, min_count=10, threshold=20, max_vocab_size=40000000>
# INFO:gensim.utils:FrozenPhrases lifecycle event {'msg': 'exported FrozenPhrases<204 phrases, min_count=10, threshold=20> from Phrases<177651 vocab, min_count=10, threshold=20, max_vocab_size=40000000> in 0.81s', 'datetime': '2021-11-05T09:32:24.120210', 'gensim': '4.1.2', 'python': '3.9.7 | packaged by conda-forge | (default, Sep 29 2021, 19:20:46) \n[GCC 9.4.0]', 'platform': 'Linux-4.15.0-159-generic-x86_64-with-glibc2.31', 'event': 'created'}

# %%
def make_bigrams(texts):
    return [bigram_model[doc] for doc in texts]

# Form Bigrams
data_words_bigrams = make_bigrams(docs)

# %%
# Checkout most frequent bigrams :
bigram_counter1= Counter()
for key in phrases.vocab.keys():
    if key not in stopwords.words('english'):
        if len(str(key).split('_'))>1:
            bigram_counter1[key]+=phrases.vocab[key]

for key, counts in bigram_counter1.most_common(20):
    print(key,">>>>", counts)
# Out:
# true_size >>>> 1317
# look_great >>>> 735
# size_small >>>> 730
# order_size >>>> 628
# size_size >>>> 524
# usual_size >>>> 496
# fabric_soft >>>> 391
# many_compliment >>>> 364
# order_small >>>> 349
# soft_comfortable >>>> 349
# love_dress >>>> 349
# skinny_jean >>>> 339
# regular_size >>>> 333
# wear_size >>>> 318
# material_soft >>>> 316
# super_soft >>>> 313
# size_large >>>> 301
# dress_look >>>> 292
# petite_size >>>> 286
# fit_true >>>> 278

# %% [markdown]
# Feeding the bigrams into a Word2Vec model produces more meaningful bigrams

# %%
# Adding business stopwords to exclude
common_terms= ["wear","look","ordered","color","purchase","order"]

stoplist= stoplist+ common_terms

# %%
w2vmodel = Word2Vec(bigram_model[docs], vector_size=100, sg=1, hs= 1, seed=33, epochs=33)
bigram_counter = Counter()

for key in w2vmodel.wv.index_to_key:
    if key not in stoplist:
        if len(str(key).split("_")) > 1:
            bigram_counter[key] += w2vmodel.wv.get_vecattr(key, "count")

for key, counts in bigram_counter.most_common(30):
    print(key,">>>>> " ,counts)
# Out:
# INFO:gensim.models.word2vec:collecting all words and their counts
# INFO:gensim.models.word2vec:PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #10000, processed 170511 words, keeping 8158 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #20000, processed 342158 words, keeping 11817 word types
# INFO:gensim.models.word2vec:collected 12697 word types from a corpus of 387611 raw words and 22641 sentences
# INFO:gensim.models.word2vec:Creating a fresh vocabulary
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'effective_min_count=5 retains 3280 unique words (25.83287390722218%% of original 12697, drops 9417)', 'datetime': '2021-11-05T09:32:51.290279', 'gensim': '4.1.2', 'python': '3.9.7 | packaged by conda-forge | (default, Sep 29 2021, 19:20:46) \n[GCC 9.4.0]', 'platform': 'Linux-4.15.0-159-generic-x86_64-with-glibc2.31', 'event': 'prepare_vocab'}
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'effective_min_count=5 leaves 374104 word corpus (96.51532077263029%% of original 387611, drops 13507)', 'datetime': '2021-11-05T09:32:51.295985', 'gensim': '4.1.2', 'python': '3.9.7 | packaged by conda-forge | (default, Sep 29 2021, 19:20:46) \n[GCC 9.4.0]', 'platform': 'Linux-4.15.0-159-generic-x86_64-with-glibc2.31', 'event': 'prepare_vocab'}
# INFO:gensim.models.word2vec:deleting the raw counts dictionary of 12697 items
# INFO:gensim.models.word2vec:sample=0.001 downsamples 73 most-common words
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 288580.1690989839 word corpus (77.1%% of prior 374104)', 'datetime': '2021-11-05T09:32:51.341416', 'gensim': '4.1.2', 'python': '3.9.7 | packaged by conda-forge | (default, Sep 29 2021, 19:20:46) \n[GCC 9.4.0]', 'platform': 'Linux-4.15.0-159-generic-x86_64-with-glibc2.31', 'event': 'prepare_vocab'}
# INFO:gensim.models.word2vec:constructing a huffman tree from 3280 words
# INFO:gensim.models.word2vec:built huffman tree with maximum node depth 16
# INFO:gensim.models.word2vec:estimated required memory for 3280 words and 100 dimensions: 6232000 bytes
# INFO:gensim.models.word2vec:resetting layer weights
# INFO:gensim.utils:Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2021-11-05T09:32:51.602912', 'gensim': '4.1.2', 'python': '3.9.7 | packaged by conda-forge | (default, Sep 29 2021, 19:20:46) \n[GCC 9.4.0]', 'platform': 'Linux-4.15.0-159-generic-x86_64-with-glibc2.31', 'event': 'build_vocab'}
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'training model with 3 workers on 3280 vocabulary and 100 features, using sg=1 hs=1 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2021-11-05T09:32:51.604280', 'gensim': '4.1.2', 'python': '3.9.7 | packaged by conda-forge | (default, Sep 29 2021, 19:20:46) \n[GCC 9.4.0]', 'platform': 'Linux-4.15.0-159-generic-x86_64-with-glibc2.31', 'event': 'train'}
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 38.86% examples, 101163 words/s, in_qsize 5, out_qsize 1
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 77.49% examples, 101913 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 1 : training on 387611 raw words (288852 effective words) took 2.5s, 114121 effective words/s
# INFO:gensim.models.word2vec:EPOCH 2 - PROGRESS: at 30.97% examples, 84819 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 2 - PROGRESS: at 67.28% examples, 92772 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 2 : training on 387611 raw words (288348 effective words) took 2.8s, 102257 effective words/s
# INFO:gensim.models.word2vec:EPOCH 3 - PROGRESS: at 36.28% examples, 96423 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 3 - PROGRESS: at 74.97% examples, 101663 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 3 : training on 387611 raw words (288709 effective words) took 2.9s, 100345 effective words/s
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 28.32% examples, 79838 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 67.25% examples, 92445 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 4 : training on 387611 raw words (288646 effective words) took 2.9s, 98051 effective words/s
# INFO:gensim.models.word2vec:EPOCH 5 - PROGRESS: at 30.99% examples, 88271 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 5 - PROGRESS: at 74.97% examples, 105603 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 5 : training on 387611 raw words (288614 effective words) took 2.7s, 108291 effective words/s
# INFO:gensim.models.word2vec:EPOCH 6 - PROGRESS: at 46.62% examples, 129523 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 6 : training on 387611 raw words (288701 effective words) took 1.9s, 149006 effective words/s
# INFO:gensim.models.word2vec:EPOCH 7 - PROGRESS: at 33.61% examples, 83209 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 7 - PROGRESS: at 69.86% examples, 90754 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 7 : training on 387611 raw words (288174 effective words) took 2.8s, 102221 effective words/s
# INFO:gensim.models.word2vec:EPOCH 8 - PROGRESS: at 46.62% examples, 131006 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 8 : training on 387611 raw words (288334 effective words) took 1.8s, 159424 effective words/s
# INFO:gensim.models.word2vec:EPOCH 9 - PROGRESS: at 25.66% examples, 68661 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 9 - PROGRESS: at 62.02% examples, 83631 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 9 : training on 387611 raw words (288558 effective words) took 2.9s, 99825 effective words/s
# INFO:gensim.models.word2vec:EPOCH 10 - PROGRESS: at 38.86% examples, 105668 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 10 - PROGRESS: at 82.59% examples, 113711 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 10 : training on 387611 raw words (288484 effective words) took 2.3s, 122950 effective words/s
# INFO:gensim.models.word2vec:EPOCH 11 - PROGRESS: at 38.89% examples, 107929 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 11 - PROGRESS: at 72.43% examples, 99823 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 11 : training on 387611 raw words (288236 effective words) took 2.8s, 102107 effective words/s
# INFO:gensim.models.word2vec:EPOCH 12 - PROGRESS: at 33.65% examples, 89582 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 12 - PROGRESS: at 77.49% examples, 105723 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 12 : training on 387611 raw words (288327 effective words) took 2.6s, 112735 effective words/s
# INFO:gensim.models.word2vec:EPOCH 13 - PROGRESS: at 49.25% examples, 138939 words/s, in_qsize 4, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 13 : training on 387611 raw words (288526 effective words) took 1.9s, 155339 effective words/s
# INFO:gensim.models.word2vec:EPOCH 14 - PROGRESS: at 33.65% examples, 89601 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 14 - PROGRESS: at 64.67% examples, 87945 words/s, in_qsize 5, out_qsize 1
# INFO:gensim.models.word2vec:EPOCH 14 - PROGRESS: at 90.27% examples, 81534 words/s, in_qsize 4, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 14 : training on 387611 raw words (288625 effective words) took 3.4s, 85842 effective words/s
# INFO:gensim.models.word2vec:EPOCH 15 - PROGRESS: at 36.28% examples, 97987 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 15 - PROGRESS: at 82.59% examples, 112219 words/s, in_qsize 6, out_qsize 1
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 15 : training on 387611 raw words (288653 effective words) took 2.4s, 120605 effective words/s
# INFO:gensim.models.word2vec:EPOCH 16 - PROGRESS: at 33.65% examples, 87591 words/s, in_qsize 5, out_qsize 1
# INFO:gensim.models.word2vec:EPOCH 16 - PROGRESS: at 69.86% examples, 93166 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 16 : training on 387611 raw words (288428 effective words) took 3.0s, 97114 effective words/s
# INFO:gensim.models.word2vec:EPOCH 17 - PROGRESS: at 33.65% examples, 93403 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 17 - PROGRESS: at 77.49% examples, 107094 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 17 : training on 387611 raw words (288297 effective words) took 2.4s, 122036 effective words/s
# INFO:gensim.models.word2vec:EPOCH 18 - PROGRESS: at 51.91% examples, 146115 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 18 : training on 387611 raw words (288583 effective words) took 1.7s, 165270 effective words/s
# INFO:gensim.models.word2vec:EPOCH 19 - PROGRESS: at 36.28% examples, 102624 words/s, in_qsize 3, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 19 - PROGRESS: at 85.12% examples, 121348 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 19 : training on 387611 raw words (288784 effective words) took 2.2s, 130694 effective words/s
# INFO:gensim.models.word2vec:EPOCH 20 - PROGRESS: at 33.65% examples, 95805 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 20 - PROGRESS: at 74.97% examples, 107278 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 20 : training on 387611 raw words (288568 effective words) took 2.4s, 121071 effective words/s
# INFO:gensim.models.word2vec:EPOCH 21 - PROGRESS: at 38.86% examples, 107858 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 21 : training on 387611 raw words (288359 effective words) took 2.0s, 141794 effective words/s
# INFO:gensim.models.word2vec:EPOCH 22 - PROGRESS: at 30.97% examples, 80567 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 22 - PROGRESS: at 72.40% examples, 93803 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 22 : training on 387611 raw words (288452 effective words) took 2.8s, 101959 effective words/s
# INFO:gensim.models.word2vec:EPOCH 23 - PROGRESS: at 28.32% examples, 79990 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 23 - PROGRESS: at 72.43% examples, 99844 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 23 : training on 387611 raw words (288814 effective words) took 2.6s, 111454 effective words/s
# INFO:gensim.models.word2vec:EPOCH 24 - PROGRESS: at 46.63% examples, 129962 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 24 : training on 387611 raw words (288492 effective words) took 2.0s, 143496 effective words/s
# INFO:gensim.models.word2vec:EPOCH 25 - PROGRESS: at 30.97% examples, 88399 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 25 - PROGRESS: at 64.67% examples, 92226 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 25 : training on 387611 raw words (288543 effective words) took 2.9s, 100240 effective words/s
# INFO:gensim.models.word2vec:EPOCH 26 - PROGRESS: at 49.25% examples, 138302 words/s, in_qsize 4, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 26 : training on 387611 raw words (288285 effective words) took 1.9s, 155663 effective words/s
# INFO:gensim.models.word2vec:EPOCH 27 - PROGRESS: at 28.32% examples, 74731 words/s, in_qsize 5, out_qsize 1
# INFO:gensim.models.word2vec:EPOCH 27 - PROGRESS: at 59.45% examples, 78657 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:EPOCH 27 - PROGRESS: at 97.44% examples, 88171 words/s, in_qsize 1, out_qsize 1
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 27 : training on 387611 raw words (288603 effective words) took 3.2s, 90319 effective words/s
# INFO:gensim.models.word2vec:EPOCH 28 - PROGRESS: at 30.97% examples, 87045 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 28 - PROGRESS: at 74.97% examples, 105660 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 28 : training on 387611 raw words (288513 effective words) took 2.5s, 113831 effective words/s
# INFO:gensim.models.word2vec:EPOCH 29 - PROGRESS: at 38.86% examples, 104607 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 29 - PROGRESS: at 74.97% examples, 103018 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 29 : training on 387611 raw words (288551 effective words) took 2.9s, 100697 effective words/s
# INFO:gensim.models.word2vec:EPOCH 30 - PROGRESS: at 28.38% examples, 73400 words/s, in_qsize 5, out_qsize 1
# INFO:gensim.models.word2vec:EPOCH 30 - PROGRESS: at 64.67% examples, 83381 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 30 : training on 387611 raw words (288577 effective words) took 3.0s, 95741 effective words/s
# INFO:gensim.models.word2vec:EPOCH 31 - PROGRESS: at 38.86% examples, 109580 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 31 - PROGRESS: at 77.49% examples, 107917 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 31 : training on 387611 raw words (288637 effective words) took 2.6s, 109056 effective words/s
# INFO:gensim.models.word2vec:EPOCH 32 - PROGRESS: at 25.72% examples, 71043 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 32 - PROGRESS: at 59.45% examples, 80355 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:EPOCH 32 - PROGRESS: at 100.00% examples, 91766 words/s, in_qsize 0, out_qsize 1
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 32 : training on 387611 raw words (288574 effective words) took 3.1s, 91702 effective words/s
# INFO:gensim.models.word2vec:EPOCH 33 - PROGRESS: at 36.28% examples, 96861 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 33 - PROGRESS: at 82.58% examples, 114016 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:EPOCH - 33 : training on 387611 raw words (288710 effective words) took 2.4s, 119259 effective words/s
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'training on 12791163 raw words (9521557 effective words) took 84.6s, 112527 effective words/s', 'datetime': '2021-11-05T09:34:16.221716', 'gensim': '4.1.2', 'python': '3.9.7 | packaged by conda-forge | (default, Sep 29 2021, 19:20:46) \n[GCC 9.4.0]', 'platform': 'Linux-4.15.0-159-generic-x86_64-with-glibc2.31', 'event': 'train'}
# INFO:gensim.utils:Word2Vec lifecycle event {'params': 'Word2Vec(vocab=3280, vector_size=100, alpha=0.025)', 'datetime': '2021-11-05T09:34:16.222958', 'gensim': '4.1.2', 'python': '3.9.7 | packaged by conda-forge | (default, Sep 29 2021, 19:20:46) \n[GCC 9.4.0]', 'platform': 'Linux-4.15.0-159-generic-x86_64-with-glibc2.31', 'event': 'created'}
# many_compliment >>>>>  364
# skinny_jean >>>>>  339
# body_type >>>>>  231
# sale_price >>>>>  220
# full_price >>>>>  209
# first_time >>>>>  204
# local_retailer >>>>>  169
# broad_shoulder >>>>>  157
# local_store >>>>>  149
# base_review >>>>>  137
# light_weight >>>>>  131
# worth_price >>>>>  128
# cami_underneath >>>>>  119
# previous_review >>>>>  110
# spring_summer >>>>>  108
# last_year >>>>>  101
# lot_compliment >>>>>  97
# read_review >>>>>  97
# pencil_skirt >>>>>  90
# right_place >>>>>  89
# athletic_build >>>>>  89
# denim_jacket >>>>>  88
# fall_winter >>>>>  88
# price_point >>>>>  79
# right_amount >>>>>  79
# real_life >>>>>  76
# tank_underneath >>>>>  75
# hand_wash >>>>>  72
# ton_compliment >>>>>  71
# hourglass_figure >>>>>  63

# %% [markdown]
# Checkout some cool stuff from the bigram model!

# %%
# MostOften mentioned along with the word 'pregnant'
w2vmodel.wv.most_similar(positive= ['pregnant'])
# Out:
# [('baby_bump', 0.5819551944732666),
#  ('pregnancy', 0.5376015901565552),
#  ('month_pregnant', 0.5323860049247742),
#  ('maternity', 0.5232221484184265),
#  ('twin', 0.49868470430374146),
#  ('sack', 0.4877704679965973),
#  ('trimester', 0.48121994733810425),
#  ('potato', 0.4309651255607605),
#  ('busty', 0.4304738938808441),
#  ('tent', 0.42559415102005005)]

# %%
# Which color is to 'work' as 'white' is to 'wedding'
# your code here
# Out:
# [('black', 0.5721330642700195),
#  ('stark', 0.5108568072319031),
#  ('navy', 0.5096889138221741),
#  ('cute', 0.4732438027858734),
#  ('cream', 0.45449140667915344)]

# %%
# your code here
# Out:
# [('sale_price', 0.43278151750564575),
#  ('steep', 0.39156848192214966),
#  ('sweater/coat', 0.39007094502449036),
#  ('expensive', 0.3879004120826721),
#  ('tracy_reese', 0.379138320684433)]

# %%
# What is a 'deal_breaker', if 'quality'is 'worth_penny' 
# your code here
# Out:
# [('exterior', 0.3735155463218689),
#  ('execution', 0.3655067980289459),
#  ('hop', 0.352865070104599)]

# %% [markdown]
# Step 4: Create a dictionary and corpus for input to our LDA model. Filter out the most common and uncommon words.

# %%
dictionary= Dictionary(data_words_bigrams)

# Filter out words that occur less than 20 documents, or more than 50% of the documents.
dictionary.filter_extremes(no_below=20, no_above=0.6)
corpus = [dictionary.doc2bow(doc) for doc in docs]

print('Number of unique tokens: %d' % len(dictionary))
print('Number of documents: %d' % len(corpus))
# Out:
# INFO:gensim.corpora.dictionary:adding document #0 to Dictionary(0 unique tokens: [])
# INFO:gensim.corpora.dictionary:adding document #10000 to Dictionary(8158 unique tokens: ['comfortable', 'sexy', 'silky', 'wonderful', 'dress']...)
# INFO:gensim.corpora.dictionary:adding document #20000 to Dictionary(11817 unique tokens: ['comfortable', 'sexy', 'silky', 'wonderful', 'dress']...)
# INFO:gensim.corpora.dictionary:built Dictionary(12697 unique tokens: ['comfortable', 'sexy', 'silky', 'wonderful', 'dress']...) from 22641 documents (total 387611 corpus positions)
# INFO:gensim.utils:Dictionary lifecycle event {'msg': "built Dictionary(12697 unique tokens: ['comfortable', 'sexy', 'silky', 'wonderful', 'dress']...) from 22641 documents (total 387611 corpus positions)", 'datetime': '2021-11-05T09:34:17.410803', 'gensim': '4.1.2', 'python': '3.9.7 | packaged by conda-forge | (default, Sep 29 2021, 19:20:46) \n[GCC 9.4.0]', 'platform': 'Linux-4.15.0-159-generic-x86_64-with-glibc2.31', 'event': 'created'}
# INFO:gensim.corpora.dictionary:discarding 11167 tokens: [('narrowing', 1), ('basket', 12), ('darkler', 1), ('ejans', 1), ('jkeep', 1), ('matvehd', 1), ('mintue', 1), ('msallet', 1), ('oops', 1), ('say', 14)]...
# INFO:gensim.corpora.dictionary:keeping 1530 tokens which were in no less than 20 and no more than 13584 (=60.0%) documents
# INFO:gensim.corpora.dictionary:resulting dictionary: Dictionary(1530 unique tokens: ['comfortable', 'sexy', 'silky', 'wonderful', 'dress']...)
# Number of unique tokens: 1530
# Number of documents: 22641

# %% [markdown]
# Step 5: Train your LDA model- Topic Modeling

# %%
from gensim.models.ldamulticore import LdaMulticore

t0= time.time()
passes= 150
np.random.seed(1) # setting up random seed to get the same results
ldamodel= LdaMulticore(corpus, 
                    id2word=dictionary, 
                    num_topics=4, 
#                   alpha='asymmetric', 
                    chunksize= 4000, 
                    batch= True,
                    minimum_probability=0.001,
                    iterations=350,
                    passes=passes)                    

t1= time.time()
print("time for",passes," passes: ",(t1-t0)," seconds")
# Out:
# INFO:gensim.models.ldamodel:using symmetric alpha at 0.25
# INFO:gensim.models.ldamodel:using symmetric eta at 0.25
# INFO:gensim.models.ldamodel:using serial LDA version on this node
# INFO:gensim.models.ldamulticore:running batch LDA training, 4 topics, 150 passes over the supplied corpus of 22641 documents, updating every 22641 documents, evaluating every ~22641 documents, iterating 350x with a convergence threshold of 0.001000
# INFO:gensim.models.ldamulticore:training LDA model using 31 processes
# INFO:gensim.models.ldamulticore:PROGRESS: pass 0, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 0, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 0, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 0, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 0, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 0, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.043*"dress" + 0.028*"size" + 0.018*"look" + 0.017*"color" + 0.013*"jean" + 0.012*"great" + 0.011*"small" + 0.011*"fabric" + 0.010*"order" + 0.010*"beautiful"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.051*"size" + 0.025*"dress" + 0.021*"great" + 0.019*"love" + 0.019*"color" + 0.018*"order" + 0.015*"fabric" + 0.014*"look" + 0.014*"beautiful" + 0.013*"little"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.032*"dress" + 0.030*"wear" + 0.021*"size" + 0.018*"color" + 0.017*"look" + 0.017*"small" + 0.016*"great" + 0.016*"fabric" + 0.014*"order" + 0.013*"love"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.025*"dress" + 0.024*"color" + 0.020*"look" + 0.018*"great" + 0.015*"size" + 0.014*"shirt" + 0.013*"wear" + 0.013*"small" + 0.013*"cute" + 0.011*"fabric"
# INFO:gensim.models.ldamodel:topic diff=1.796459, rho=1.000000
# INFO:gensim.models.ldamodel:-6.204 per-word bound, 73.7 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 1, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 1, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 1, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 1, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 1, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 1, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.045*"dress" + 0.027*"size" + 0.018*"look" + 0.016*"color" + 0.014*"jean" + 0.011*"great" + 0.011*"small" + 0.011*"fabric" + 0.010*"waist" + 0.010*"beautiful"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.054*"size" + 0.024*"dress" + 0.021*"great" + 0.019*"love" + 0.019*"order" + 0.019*"color" + 0.015*"fabric" + 0.014*"beautiful" + 0.013*"look" + 0.013*"little"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.034*"dress" + 0.031*"wear" + 0.020*"size" + 0.018*"color" + 0.017*"small" + 0.016*"look" + 0.016*"great" + 0.016*"fabric" + 0.014*"order" + 0.013*"love"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.024*"color" + 0.022*"dress" + 0.021*"look" + 0.019*"great" + 0.016*"shirt" + 0.013*"cute" + 0.013*"size" + 0.013*"wear" + 0.012*"small" + 0.010*"fabric"
# INFO:gensim.models.ldamodel:topic diff=0.070505, rho=0.361309
# INFO:gensim.models.ldamodel:-6.196 per-word bound, 73.3 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 2, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 2, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 2, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 2, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 2, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 2, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.047*"dress" + 0.027*"size" + 0.018*"look" + 0.016*"color" + 0.014*"jean" + 0.011*"waist" + 0.011*"fabric" + 0.011*"small" + 0.011*"great" + 0.010*"beautiful"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.058*"size" + 0.023*"dress" + 0.021*"great" + 0.020*"order" + 0.019*"color" + 0.019*"love" + 0.016*"fabric" + 0.014*"beautiful" + 0.013*"little" + 0.013*"look"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.035*"dress" + 0.032*"wear" + 0.019*"size" + 0.018*"small" + 0.017*"color" + 0.017*"great" + 0.016*"look" + 0.016*"fabric" + 0.013*"order" + 0.013*"love"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.024*"color" + 0.022*"look" + 0.019*"dress" + 0.019*"great" + 0.018*"shirt" + 0.014*"cute" + 0.013*"wear" + 0.012*"small" + 0.012*"size" + 0.011*"soft"
# INFO:gensim.models.ldamodel:topic diff=0.066802, rho=0.339809
# INFO:gensim.models.ldamodel:-6.187 per-word bound, 72.9 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 3, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 3, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 3, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 3, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 3, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 3, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.049*"dress" + 0.026*"size" + 0.018*"look" + 0.016*"color" + 0.014*"jean" + 0.012*"waist" + 0.011*"fabric" + 0.010*"small" + 0.010*"beautiful" + 0.010*"great"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.061*"size" + 0.022*"dress" + 0.021*"order" + 0.021*"great" + 0.020*"color" + 0.019*"love" + 0.016*"fabric" + 0.014*"beautiful" + 0.013*"little" + 0.013*"look"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.037*"dress" + 0.033*"wear" + 0.018*"small" + 0.018*"size" + 0.017*"great" + 0.017*"color" + 0.016*"look" + 0.016*"fabric" + 0.014*"love" + 0.013*"order"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.025*"color" + 0.022*"look" + 0.019*"shirt" + 0.019*"great" + 0.017*"dress" + 0.015*"cute" + 0.013*"wear" + 0.011*"soft" + 0.011*"small" + 0.010*"size"
# INFO:gensim.models.ldamodel:topic diff=0.064827, rho=0.321741
# INFO:gensim.models.ldamodel:-6.179 per-word bound, 72.5 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 4, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 4, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 4, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 4, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 4, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 4, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.050*"dress" + 0.026*"size" + 0.018*"look" + 0.016*"color" + 0.014*"jean" + 0.013*"waist" + 0.011*"fabric" + 0.011*"length" + 0.010*"beautiful" + 0.010*"small"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.064*"size" + 0.022*"order" + 0.021*"dress" + 0.020*"great" + 0.020*"color" + 0.019*"love" + 0.016*"fabric" + 0.014*"beautiful" + 0.013*"little" + 0.012*"look"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.038*"dress" + 0.034*"wear" + 0.018*"great" + 0.018*"small" + 0.017*"size" + 0.016*"color" + 0.016*"look" + 0.015*"fabric" + 0.014*"love" + 0.012*"order"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.025*"color" + 0.023*"look" + 0.020*"shirt" + 0.019*"great" + 0.015*"cute" + 0.014*"dress" + 0.013*"wear" + 0.011*"soft" + 0.011*"sweater" + 0.010*"small"
# INFO:gensim.models.ldamodel:topic diff=0.062696, rho=0.306278
# INFO:gensim.models.ldamodel:-6.172 per-word bound, 72.1 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 5, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 5, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 5, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 5, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 5, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 5, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.052*"dress" + 0.025*"size" + 0.018*"look" + 0.015*"color" + 0.014*"waist" + 0.014*"jean" + 0.012*"fabric" + 0.011*"length" + 0.011*"petite" + 0.010*"beautiful"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.067*"size" + 0.023*"order" + 0.020*"color" + 0.020*"great" + 0.020*"dress" + 0.019*"love" + 0.016*"fabric" + 0.014*"beautiful" + 0.013*"little" + 0.012*"small"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.040*"dress" + 0.034*"wear" + 0.019*"great" + 0.018*"small" + 0.016*"color" + 0.016*"size" + 0.015*"look" + 0.015*"fabric" + 0.014*"love" + 0.013*"comfortable"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.025*"color" + 0.023*"look" + 0.021*"shirt" + 0.019*"great" + 0.015*"cute" + 0.013*"wear" + 0.012*"dress" + 0.012*"soft" + 0.012*"sweater" + 0.010*"little"
# INFO:gensim.models.ldamodel:topic diff=0.060871, rho=0.292851
# INFO:gensim.models.ldamodel:-6.165 per-word bound, 71.7 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 6, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 6, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 6, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 6, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 6, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 6, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.053*"dress" + 0.025*"size" + 0.019*"look" + 0.015*"color" + 0.015*"waist" + 0.014*"jean" + 0.012*"fabric" + 0.012*"length" + 0.011*"petite" + 0.010*"beautiful"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.069*"size" + 0.024*"order" + 0.020*"color" + 0.019*"great" + 0.019*"dress" + 0.019*"love" + 0.016*"fabric" + 0.014*"beautiful" + 0.013*"small" + 0.013*"little"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.041*"dress" + 0.035*"wear" + 0.019*"great" + 0.017*"small" + 0.016*"color" + 0.015*"look" + 0.015*"fabric" + 0.015*"size" + 0.015*"love" + 0.013*"comfortable"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.026*"color" + 0.023*"look" + 0.022*"shirt" + 0.020*"great" + 0.015*"cute" + 0.012*"wear" + 0.012*"sweater" + 0.012*"soft" + 0.011*"dress" + 0.010*"little"
# INFO:gensim.models.ldamodel:topic diff=0.058701, rho=0.281047
# INFO:gensim.models.ldamodel:-6.158 per-word bound, 71.4 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 7, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 7, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 7, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 7, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 7, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 7, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.054*"dress" + 0.024*"size" + 0.019*"look" + 0.016*"waist" + 0.015*"color" + 0.013*"jean" + 0.013*"fabric" + 0.012*"length" + 0.012*"petite" + 0.010*"beautiful"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.072*"size" + 0.025*"order" + 0.020*"color" + 0.018*"great" + 0.018*"love" + 0.018*"dress" + 0.016*"fabric" + 0.014*"small" + 0.014*"beautiful" + 0.013*"little"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.042*"dress" + 0.036*"wear" + 0.020*"great" + 0.017*"small" + 0.016*"color" + 0.015*"love" + 0.015*"look" + 0.014*"fabric" + 0.014*"size" + 0.014*"comfortable"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.026*"color" + 0.024*"look" + 0.023*"shirt" + 0.020*"great" + 0.015*"cute" + 0.013*"sweater" + 0.013*"soft" + 0.012*"wear" + 0.010*"little" + 0.009*"dress"
# INFO:gensim.models.ldamodel:topic diff=0.057184, rho=0.270564
# INFO:gensim.models.ldamodel:-6.152 per-word bound, 71.1 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 8, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 8, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 8, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 8, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 8, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 8, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.055*"dress" + 0.024*"size" + 0.019*"look" + 0.016*"waist" + 0.015*"color" + 0.013*"jean" + 0.013*"fabric" + 0.012*"length" + 0.012*"petite" + 0.010*"beautiful"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.074*"size" + 0.026*"order" + 0.020*"color" + 0.018*"great" + 0.018*"love" + 0.017*"dress" + 0.016*"fabric" + 0.016*"small" + 0.014*"beautiful" + 0.013*"true"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.043*"dress" + 0.036*"wear" + 0.021*"great" + 0.016*"small" + 0.016*"color" + 0.015*"love" + 0.014*"look" + 0.014*"comfortable" + 0.014*"fabric" + 0.014*"perfect"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.027*"color" + 0.024*"look" + 0.024*"shirt" + 0.019*"great" + 0.015*"cute" + 0.014*"sweater" + 0.013*"soft" + 0.012*"wear" + 0.010*"little" + 0.009*"love"
# INFO:gensim.models.ldamodel:topic diff=0.055657, rho=0.261174
# INFO:gensim.models.ldamodel:-6.146 per-word bound, 70.8 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 9, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 9, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 9, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 9, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 9, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 9, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.056*"dress" + 0.023*"size" + 0.019*"look" + 0.017*"waist" + 0.014*"color" + 0.013*"fabric" + 0.013*"length" + 0.013*"jean" + 0.012*"petite" + 0.010*"beautiful"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.075*"size" + 0.027*"order" + 0.020*"color" + 0.017*"love" + 0.017*"great" + 0.017*"small" + 0.016*"dress" + 0.016*"fabric" + 0.014*"beautiful" + 0.013*"true"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.045*"dress" + 0.036*"wear" + 0.022*"great" + 0.016*"love" + 0.015*"color" + 0.015*"small" + 0.015*"comfortable" + 0.014*"look" + 0.014*"perfect" + 0.014*"fabric"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.027*"color" + 0.024*"shirt" + 0.024*"look" + 0.019*"great" + 0.015*"cute" + 0.014*"sweater" + 0.013*"soft" + 0.012*"wear" + 0.011*"little" + 0.010*"white"
# INFO:gensim.models.ldamodel:topic diff=0.054035, rho=0.252697
# INFO:gensim.models.ldamodel:-6.140 per-word bound, 70.5 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 10, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 10, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 10, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 10, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 10, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 10, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.057*"dress" + 0.023*"size" + 0.019*"look" + 0.017*"waist" + 0.014*"color" + 0.014*"fabric" + 0.013*"length" + 0.012*"petite" + 0.012*"jean" + 0.010*"beautiful"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.077*"size" + 0.027*"order" + 0.019*"color" + 0.019*"small" + 0.017*"love" + 0.017*"great" + 0.016*"fabric" + 0.016*"dress" + 0.014*"true" + 0.013*"beautiful"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.046*"dress" + 0.037*"wear" + 0.023*"great" + 0.016*"love" + 0.015*"color" + 0.015*"comfortable" + 0.015*"small" + 0.015*"perfect" + 0.014*"look" + 0.013*"fabric"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.028*"color" + 0.024*"shirt" + 0.024*"look" + 0.019*"great" + 0.015*"cute" + 0.014*"sweater" + 0.013*"soft" + 0.012*"wear" + 0.011*"little" + 0.010*"white"
# INFO:gensim.models.ldamodel:topic diff=0.052292, rho=0.244996
# INFO:gensim.models.ldamodel:-6.135 per-word bound, 70.3 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 11, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 11, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 11, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 11, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 11, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 11, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.058*"dress" + 0.022*"size" + 0.019*"look" + 0.017*"waist" + 0.014*"fabric" + 0.014*"color" + 0.013*"length" + 0.013*"petite" + 0.012*"jean" + 0.010*"skirt"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.079*"size" + 0.028*"order" + 0.020*"small" + 0.019*"color" + 0.017*"love" + 0.016*"great" + 0.016*"fabric" + 0.015*"dress" + 0.014*"large" + 0.014*"true"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.046*"dress" + 0.037*"wear" + 0.024*"great" + 0.016*"love" + 0.016*"comfortable" + 0.015*"color" + 0.015*"perfect" + 0.014*"look" + 0.014*"small" + 0.013*"fabric"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.028*"color" + 0.025*"shirt" + 0.024*"look" + 0.019*"great" + 0.015*"cute" + 0.015*"sweater" + 0.014*"soft" + 0.012*"wear" + 0.011*"little" + 0.010*"white"
# INFO:gensim.models.ldamodel:topic diff=0.050505, rho=0.237959
# INFO:gensim.models.ldamodel:-6.131 per-word bound, 70.1 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 12, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 12, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 12, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 12, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 12, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 12, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.058*"dress" + 0.022*"size" + 0.020*"look" + 0.018*"waist" + 0.015*"fabric" + 0.014*"color" + 0.013*"length" + 0.013*"petite" + 0.011*"jean" + 0.011*"skirt"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.080*"size" + 0.029*"order" + 0.021*"small" + 0.019*"color" + 0.016*"love" + 0.016*"great" + 0.016*"fabric" + 0.015*"large" + 0.014*"dress" + 0.014*"true"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.047*"dress" + 0.037*"wear" + 0.024*"great" + 0.017*"love" + 0.016*"comfortable" + 0.016*"perfect" + 0.015*"color" + 0.014*"look" + 0.013*"small" + 0.013*"fabric"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.029*"color" + 0.025*"shirt" + 0.024*"look" + 0.019*"great" + 0.015*"sweater" + 0.015*"cute" + 0.014*"soft" + 0.012*"wear" + 0.011*"little" + 0.010*"white"
# INFO:gensim.models.ldamodel:topic diff=0.048760, rho=0.231495
# INFO:gensim.models.ldamodel:-6.126 per-word bound, 69.9 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 13, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 13, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 13, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 13, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 13, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 13, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.059*"dress" + 0.021*"size" + 0.020*"look" + 0.018*"waist" + 0.015*"fabric" + 0.013*"length" + 0.013*"color" + 0.013*"petite" + 0.011*"jean" + 0.011*"skirt"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.081*"size" + 0.030*"order" + 0.023*"small" + 0.019*"color" + 0.016*"love" + 0.016*"great" + 0.015*"fabric" + 0.015*"large" + 0.014*"true" + 0.014*"dress"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.048*"dress" + 0.037*"wear" + 0.025*"great" + 0.017*"love" + 0.016*"comfortable" + 0.016*"perfect" + 0.015*"color" + 0.014*"look" + 0.012*"small" + 0.012*"fabric"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.029*"color" + 0.025*"shirt" + 0.024*"look" + 0.019*"great" + 0.016*"sweater" + 0.015*"cute" + 0.014*"soft" + 0.012*"wear" + 0.011*"little" + 0.011*"white"
# INFO:gensim.models.ldamodel:topic diff=0.047149, rho=0.225531
# INFO:gensim.models.ldamodel:-6.122 per-word bound, 69.7 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 14, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 14, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 14, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 14, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 14, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 14, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.059*"dress" + 0.021*"size" + 0.020*"look" + 0.018*"waist" + 0.015*"fabric" + 0.014*"length" + 0.013*"color" + 0.013*"petite" + 0.011*"skirt" + 0.011*"jean"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.083*"size" + 0.030*"order" + 0.024*"small" + 0.019*"color" + 0.016*"large" + 0.016*"love" + 0.015*"great" + 0.015*"fabric" + 0.015*"true" + 0.013*"dress"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.048*"dress" + 0.037*"wear" + 0.026*"great" + 0.017*"love" + 0.017*"comfortable" + 0.017*"perfect" + 0.015*"color" + 0.013*"look" + 0.012*"fabric" + 0.012*"small"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.029*"color" + 0.025*"shirt" + 0.024*"look" + 0.019*"great" + 0.016*"sweater" + 0.015*"cute" + 0.014*"soft" + 0.012*"wear" + 0.011*"little" + 0.011*"white"
# INFO:gensim.models.ldamodel:topic diff=0.045631, rho=0.220005
# INFO:gensim.models.ldamodel:-6.119 per-word bound, 69.5 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 15, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 15, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 15, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 15, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 15, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 15, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.060*"dress" + 0.021*"size" + 0.020*"look" + 0.019*"waist" + 0.016*"fabric" + 0.014*"length" + 0.013*"color" + 0.013*"petite" + 0.011*"skirt" + 0.010*"jean"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.084*"size" + 0.031*"order" + 0.025*"small" + 0.018*"color" + 0.016*"large" + 0.015*"love" + 0.015*"fabric" + 0.015*"great" + 0.015*"true" + 0.013*"dress"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.049*"dress" + 0.038*"wear" + 0.026*"great" + 0.017*"love" + 0.017*"perfect" + 0.017*"comfortable" + 0.016*"color" + 0.013*"look" + 0.012*"fabric" + 0.011*"soft"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.030*"color" + 0.026*"shirt" + 0.024*"look" + 0.018*"great" + 0.016*"sweater" + 0.015*"cute" + 0.014*"soft" + 0.012*"wear" + 0.011*"white" + 0.011*"little"
# INFO:gensim.models.ldamodel:topic diff=0.044366, rho=0.214866
# INFO:gensim.models.ldamodel:-6.116 per-word bound, 69.4 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 16, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 16, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 16, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 16, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 16, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 16, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.060*"dress" + 0.020*"look" + 0.020*"size" + 0.019*"waist" + 0.016*"fabric" + 0.014*"length" + 0.013*"petite" + 0.013*"color" + 0.012*"skirt" + 0.010*"jean"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.085*"size" + 0.031*"order" + 0.026*"small" + 0.018*"color" + 0.017*"large" + 0.015*"love" + 0.015*"true" + 0.015*"fabric" + 0.015*"great" + 0.013*"dress"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.049*"dress" + 0.038*"wear" + 0.027*"great" + 0.018*"perfect" + 0.018*"love" + 0.017*"comfortable" + 0.016*"color" + 0.013*"look" + 0.011*"fabric" + 0.011*"compliment"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.030*"color" + 0.026*"shirt" + 0.024*"look" + 0.018*"great" + 0.016*"sweater" + 0.015*"cute" + 0.015*"soft" + 0.012*"wear" + 0.011*"white" + 0.011*"little"
# INFO:gensim.models.ldamodel:topic diff=0.043009, rho=0.210072
# INFO:gensim.models.ldamodel:-6.113 per-word bound, 69.2 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 17, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 17, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 17, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 17, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 17, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 17, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.061*"dress" + 0.020*"look" + 0.020*"size" + 0.019*"waist" + 0.016*"fabric" + 0.014*"length" + 0.013*"petite" + 0.013*"color" + 0.012*"skirt" + 0.010*"beautiful"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.086*"size" + 0.032*"order" + 0.027*"small" + 0.018*"color" + 0.018*"large" + 0.015*"true" + 0.015*"love" + 0.014*"fabric" + 0.014*"great" + 0.012*"fit"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.049*"dress" + 0.038*"wear" + 0.028*"great" + 0.018*"perfect" + 0.018*"love" + 0.018*"comfortable" + 0.016*"color" + 0.013*"look" + 0.012*"compliment" + 0.011*"soft"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.030*"color" + 0.026*"shirt" + 0.024*"look" + 0.018*"great" + 0.016*"sweater" + 0.015*"soft" + 0.014*"cute" + 0.012*"wear" + 0.011*"white" + 0.011*"love"
# INFO:gensim.models.ldamodel:topic diff=0.041690, rho=0.205584
# INFO:gensim.models.ldamodel:-6.111 per-word bound, 69.1 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 18, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 18, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 18, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 18, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 18, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 18, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.061*"dress" + 0.020*"look" + 0.020*"size" + 0.019*"waist" + 0.017*"fabric" + 0.014*"length" + 0.013*"petite" + 0.012*"color" + 0.012*"skirt" + 0.010*"beautiful"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.087*"size" + 0.032*"order" + 0.028*"small" + 0.018*"large" + 0.018*"color" + 0.015*"true" + 0.015*"love" + 0.014*"fabric" + 0.014*"great" + 0.013*"fit"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.050*"dress" + 0.038*"wear" + 0.028*"great" + 0.018*"perfect" + 0.018*"comfortable" + 0.018*"love" + 0.016*"color" + 0.013*"look" + 0.012*"compliment" + 0.011*"soft"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.030*"color" + 0.026*"shirt" + 0.025*"look" + 0.018*"great" + 0.017*"sweater" + 0.015*"soft" + 0.014*"cute" + 0.012*"wear" + 0.011*"white" + 0.011*"love"
# INFO:gensim.models.ldamodel:topic diff=0.040417, rho=0.201373
# INFO:gensim.models.ldamodel:-6.108 per-word bound, 69.0 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 19, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 19, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 19, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 19, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 19, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 19, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.062*"dress" + 0.021*"look" + 0.019*"waist" + 0.019*"size" + 0.017*"fabric" + 0.014*"length" + 0.013*"petite" + 0.012*"color" + 0.012*"skirt" + 0.010*"beautiful"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.088*"size" + 0.033*"order" + 0.029*"small" + 0.019*"large" + 0.018*"color" + 0.015*"true" + 0.014*"love" + 0.014*"fabric" + 0.014*"great" + 0.013*"medium"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.050*"dress" + 0.038*"wear" + 0.029*"great" + 0.019*"perfect" + 0.018*"comfortable" + 0.018*"love" + 0.016*"color" + 0.013*"look" + 0.012*"compliment" + 0.012*"soft"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.031*"color" + 0.026*"shirt" + 0.025*"look" + 0.018*"great" + 0.017*"sweater" + 0.015*"soft" + 0.014*"cute" + 0.012*"wear" + 0.011*"white" + 0.011*"love"
# INFO:gensim.models.ldamodel:topic diff=0.039207, rho=0.197410
# INFO:gensim.models.ldamodel:-6.106 per-word bound, 68.9 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 20, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 20, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 20, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 20, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 20, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 20, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.062*"dress" + 0.021*"look" + 0.019*"waist" + 0.019*"size" + 0.017*"fabric" + 0.014*"length" + 0.013*"petite" + 0.012*"skirt" + 0.012*"color" + 0.010*"short"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.089*"size" + 0.033*"order" + 0.030*"small" + 0.019*"large" + 0.018*"color" + 0.015*"true" + 0.014*"love" + 0.014*"fabric" + 0.014*"medium" + 0.014*"great"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.050*"dress" + 0.038*"wear" + 0.029*"great" + 0.019*"perfect" + 0.018*"comfortable" + 0.018*"love" + 0.016*"color" + 0.013*"look" + 0.012*"compliment" + 0.012*"soft"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.031*"color" + 0.026*"shirt" + 0.025*"look" + 0.017*"great" + 0.017*"sweater" + 0.015*"soft" + 0.014*"cute" + 0.012*"wear" + 0.012*"white" + 0.011*"love"
# INFO:gensim.models.ldamodel:topic diff=0.038059, rho=0.193672
# INFO:gensim.models.ldamodel:-6.104 per-word bound, 68.8 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 21, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 21, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 21, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 21, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 21, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 21, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.063*"dress" + 0.021*"look" + 0.020*"waist" + 0.019*"size" + 0.017*"fabric" + 0.014*"length" + 0.013*"petite" + 0.013*"skirt" + 0.012*"color" + 0.010*"short"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.090*"size" + 0.034*"order" + 0.031*"small" + 0.019*"large" + 0.017*"color" + 0.016*"true" + 0.014*"medium" + 0.014*"love" + 0.014*"fabric" + 0.013*"great"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.050*"dress" + 0.038*"wear" + 0.030*"great" + 0.019*"perfect" + 0.019*"comfortable" + 0.018*"love" + 0.016*"color" + 0.013*"look" + 0.012*"compliment" + 0.012*"soft"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.031*"color" + 0.026*"shirt" + 0.025*"look" + 0.017*"great" + 0.017*"sweater" + 0.015*"soft" + 0.014*"cute" + 0.012*"wear" + 0.012*"white" + 0.011*"love"
# INFO:gensim.models.ldamodel:topic diff=0.036949, rho=0.190139
# INFO:gensim.models.ldamodel:-6.102 per-word bound, 68.7 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 22, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 22, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 22, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 22, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 22, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 22, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.063*"dress" + 0.021*"look" + 0.020*"waist" + 0.018*"size" + 0.018*"fabric" + 0.014*"length" + 0.013*"petite" + 0.013*"skirt" + 0.012*"color" + 0.010*"short"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.091*"size" + 0.034*"order" + 0.032*"small" + 0.020*"large" + 0.017*"color" + 0.016*"true" + 0.015*"medium" + 0.014*"love" + 0.013*"fabric" + 0.013*"great"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.050*"dress" + 0.038*"wear" + 0.030*"great" + 0.020*"perfect" + 0.019*"comfortable" + 0.019*"love" + 0.016*"color" + 0.013*"look" + 0.012*"compliment" + 0.012*"soft"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.031*"color" + 0.026*"shirt" + 0.025*"look" + 0.017*"sweater" + 0.017*"great" + 0.015*"soft" + 0.014*"cute" + 0.012*"wear" + 0.012*"white" + 0.011*"love"
# INFO:gensim.models.ldamodel:topic diff=0.035923, rho=0.186793
# INFO:gensim.models.ldamodel:-6.101 per-word bound, 68.6 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 23, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 23, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 23, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 23, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 23, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 23, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.063*"dress" + 0.021*"look" + 0.020*"waist" + 0.018*"size" + 0.018*"fabric" + 0.014*"length" + 0.013*"skirt" + 0.013*"petite" + 0.012*"color" + 0.010*"short"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.092*"size" + 0.034*"order" + 0.033*"small" + 0.020*"large" + 0.017*"color" + 0.016*"true" + 0.015*"medium" + 0.013*"love" + 0.013*"fabric" + 0.013*"fit"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.050*"dress" + 0.038*"wear" + 0.030*"great" + 0.020*"perfect" + 0.019*"comfortable" + 0.019*"love" + 0.016*"color" + 0.013*"look" + 0.012*"compliment" + 0.012*"soft"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.031*"color" + 0.026*"shirt" + 0.025*"look" + 0.017*"sweater" + 0.017*"great" + 0.015*"soft" + 0.014*"cute" + 0.012*"wear" + 0.012*"white" + 0.012*"love"
# INFO:gensim.models.ldamodel:topic diff=0.034888, rho=0.183617
# INFO:gensim.models.ldamodel:-6.099 per-word bound, 68.5 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 24, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 24, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 24, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 24, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 24, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 24, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.064*"dress" + 0.021*"look" + 0.020*"waist" + 0.018*"size" + 0.018*"fabric" + 0.014*"length" + 0.013*"skirt" + 0.013*"petite" + 0.012*"color" + 0.010*"short"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.093*"size" + 0.035*"order" + 0.034*"small" + 0.021*"large" + 0.017*"color" + 0.016*"true" + 0.016*"medium" + 0.013*"love" + 0.013*"fit" + 0.013*"fabric"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.050*"dress" + 0.038*"wear" + 0.031*"great" + 0.020*"perfect" + 0.019*"comfortable" + 0.019*"love" + 0.016*"color" + 0.013*"look" + 0.012*"compliment" + 0.012*"soft"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.032*"color" + 0.026*"shirt" + 0.025*"look" + 0.017*"sweater" + 0.017*"great" + 0.015*"soft" + 0.014*"cute" + 0.012*"wear" + 0.012*"white" + 0.012*"love"
# INFO:gensim.models.ldamodel:topic diff=0.033965, rho=0.180598
# INFO:gensim.models.ldamodel:-6.098 per-word bound, 68.5 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 25, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 25, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 25, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 25, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 25, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 25, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.064*"dress" + 0.021*"look" + 0.020*"waist" + 0.018*"fabric" + 0.018*"size" + 0.014*"length" + 0.013*"skirt" + 0.013*"petite" + 0.011*"color" + 0.010*"short"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.094*"size" + 0.035*"order" + 0.034*"small" + 0.021*"large" + 0.017*"color" + 0.016*"medium" + 0.016*"true" + 0.013*"fit" + 0.013*"love" + 0.013*"fabric"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.050*"dress" + 0.038*"wear" + 0.031*"great" + 0.021*"perfect" + 0.019*"comfortable" + 0.019*"love" + 0.016*"color" + 0.013*"look" + 0.012*"compliment" + 0.012*"soft"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.032*"color" + 0.026*"shirt" + 0.025*"look" + 0.017*"sweater" + 0.017*"great" + 0.015*"soft" + 0.014*"cute" + 0.012*"wear" + 0.012*"white" + 0.012*"love"
# INFO:gensim.models.ldamodel:topic diff=0.033004, rho=0.177723
# INFO:gensim.models.ldamodel:-6.096 per-word bound, 68.4 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 26, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 26, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 26, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 26, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 26, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 26, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.064*"dress" + 0.021*"look" + 0.020*"waist" + 0.018*"fabric" + 0.017*"size" + 0.014*"length" + 0.013*"skirt" + 0.013*"petite" + 0.011*"color" + 0.010*"short"
# ...
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.083*"dress" + 0.023*"waist" + 0.023*"look" + 0.023*"fabric" + 0.015*"skirt" + 0.012*"length" + 0.011*"beautiful" + 0.010*"material" + 0.010*"short" + 0.010*"flatter"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.126*"size" + 0.054*"small" + 0.047*"order" + 0.031*"large" + 0.027*"medium" + 0.021*"true" + 0.017*"fit" + 0.016*"petite" + 0.014*"store" + 0.013*"retailer"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.041*"great" + 0.039*"dress" + 0.037*"wear" + 0.027*"jean" + 0.026*"perfect" + 0.022*"comfortable" + 0.022*"love" + 0.020*"color" + 0.017*"pant" + 0.015*"summer"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.034*"color" + 0.026*"shirt" + 0.024*"look" + 0.018*"sweater" + 0.017*"fabric" + 0.015*"soft" + 0.013*"white" + 0.012*"nice" + 0.012*"love" + 0.011*"little"
# INFO:gensim.models.ldamodel:topic diff=0.004076, rho=0.082294
# INFO:gensim.models.ldamodel:-6.068 per-word bound, 67.1 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 142, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 142, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 142, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 142, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 142, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 142, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.083*"dress" + 0.023*"waist" + 0.023*"look" + 0.023*"fabric" + 0.015*"skirt" + 0.012*"length" + 0.011*"beautiful" + 0.010*"material" + 0.010*"short" + 0.010*"flatter"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.126*"size" + 0.054*"small" + 0.047*"order" + 0.031*"large" + 0.027*"medium" + 0.021*"true" + 0.017*"fit" + 0.016*"petite" + 0.014*"store" + 0.013*"retailer"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.042*"great" + 0.039*"dress" + 0.037*"wear" + 0.027*"jean" + 0.026*"perfect" + 0.022*"comfortable" + 0.022*"love" + 0.020*"color" + 0.017*"pant" + 0.015*"summer"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.034*"color" + 0.026*"shirt" + 0.024*"look" + 0.018*"sweater" + 0.017*"fabric" + 0.015*"soft" + 0.013*"white" + 0.012*"nice" + 0.012*"love" + 0.011*"little"
# INFO:gensim.models.ldamodel:topic diff=0.004034, rho=0.082017
# INFO:gensim.models.ldamodel:-6.068 per-word bound, 67.1 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 143, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 143, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 143, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 143, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 143, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 143, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.083*"dress" + 0.023*"waist" + 0.023*"look" + 0.023*"fabric" + 0.015*"skirt" + 0.012*"length" + 0.011*"beautiful" + 0.010*"material" + 0.010*"short" + 0.010*"flatter"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.127*"size" + 0.054*"small" + 0.048*"order" + 0.031*"large" + 0.027*"medium" + 0.021*"true" + 0.017*"fit" + 0.016*"petite" + 0.014*"store" + 0.013*"retailer"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.042*"great" + 0.039*"dress" + 0.037*"wear" + 0.027*"jean" + 0.026*"perfect" + 0.022*"comfortable" + 0.022*"love" + 0.020*"color" + 0.017*"pant" + 0.015*"summer"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.034*"color" + 0.026*"shirt" + 0.024*"look" + 0.018*"sweater" + 0.017*"fabric" + 0.015*"soft" + 0.013*"white" + 0.012*"nice" + 0.012*"love" + 0.011*"little"
# INFO:gensim.models.ldamodel:topic diff=0.003985, rho=0.081742
# INFO:gensim.models.ldamodel:-6.068 per-word bound, 67.1 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 144, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 144, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 144, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 144, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 144, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 144, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.083*"dress" + 0.023*"waist" + 0.023*"look" + 0.023*"fabric" + 0.015*"skirt" + 0.012*"length" + 0.011*"beautiful" + 0.010*"material" + 0.010*"short" + 0.010*"flatter"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.127*"size" + 0.054*"small" + 0.048*"order" + 0.031*"large" + 0.027*"medium" + 0.021*"true" + 0.017*"fit" + 0.016*"petite" + 0.014*"store" + 0.013*"retailer"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.042*"great" + 0.038*"dress" + 0.037*"wear" + 0.027*"jean" + 0.026*"perfect" + 0.022*"comfortable" + 0.022*"love" + 0.020*"color" + 0.017*"pant" + 0.015*"summer"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.034*"color" + 0.026*"shirt" + 0.024*"look" + 0.018*"sweater" + 0.017*"fabric" + 0.015*"soft" + 0.013*"white" + 0.012*"nice" + 0.012*"love" + 0.011*"little"
# INFO:gensim.models.ldamodel:topic diff=0.003936, rho=0.081471
# INFO:gensim.models.ldamodel:-6.068 per-word bound, 67.1 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 145, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 145, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 145, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 145, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 145, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 145, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.083*"dress" + 0.023*"waist" + 0.023*"look" + 0.023*"fabric" + 0.015*"skirt" + 0.012*"length" + 0.011*"beautiful" + 0.010*"material" + 0.010*"short" + 0.010*"flatter"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.127*"size" + 0.054*"small" + 0.048*"order" + 0.031*"large" + 0.027*"medium" + 0.021*"true" + 0.017*"fit" + 0.016*"petite" + 0.014*"store" + 0.013*"retailer"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.042*"great" + 0.038*"dress" + 0.037*"wear" + 0.027*"jean" + 0.026*"perfect" + 0.022*"comfortable" + 0.022*"love" + 0.020*"color" + 0.017*"pant" + 0.015*"summer"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.034*"color" + 0.026*"shirt" + 0.024*"look" + 0.018*"sweater" + 0.017*"fabric" + 0.015*"soft" + 0.013*"white" + 0.012*"nice" + 0.012*"love" + 0.011*"little"
# INFO:gensim.models.ldamodel:topic diff=0.003898, rho=0.081202
# INFO:gensim.models.ldamodel:-6.068 per-word bound, 67.1 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 146, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 146, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 146, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 146, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 146, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 146, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.083*"dress" + 0.023*"waist" + 0.023*"look" + 0.023*"fabric" + 0.015*"skirt" + 0.012*"length" + 0.011*"beautiful" + 0.010*"material" + 0.010*"short" + 0.010*"flatter"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.127*"size" + 0.054*"small" + 0.048*"order" + 0.031*"large" + 0.027*"medium" + 0.021*"true" + 0.017*"fit" + 0.016*"petite" + 0.014*"store" + 0.013*"retailer"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.042*"great" + 0.038*"dress" + 0.037*"wear" + 0.027*"jean" + 0.026*"perfect" + 0.022*"comfortable" + 0.022*"love" + 0.020*"color" + 0.017*"pant" + 0.015*"summer"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.034*"color" + 0.026*"shirt" + 0.024*"look" + 0.018*"sweater" + 0.017*"fabric" + 0.015*"soft" + 0.013*"white" + 0.012*"nice" + 0.012*"love" + 0.011*"little"
# INFO:gensim.models.ldamodel:topic diff=0.003857, rho=0.080935
# INFO:gensim.models.ldamodel:-6.068 per-word bound, 67.1 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 147, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 147, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 147, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 147, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 147, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 147, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.083*"dress" + 0.023*"waist" + 0.023*"look" + 0.023*"fabric" + 0.015*"skirt" + 0.012*"length" + 0.011*"beautiful" + 0.010*"material" + 0.010*"flatter" + 0.010*"short"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.127*"size" + 0.054*"small" + 0.048*"order" + 0.031*"large" + 0.027*"medium" + 0.021*"true" + 0.017*"fit" + 0.016*"petite" + 0.014*"store" + 0.013*"retailer"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.042*"great" + 0.038*"dress" + 0.037*"wear" + 0.027*"jean" + 0.026*"perfect" + 0.022*"comfortable" + 0.022*"love" + 0.020*"color" + 0.017*"pant" + 0.015*"summer"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.034*"color" + 0.026*"shirt" + 0.024*"look" + 0.018*"sweater" + 0.017*"fabric" + 0.015*"soft" + 0.013*"white" + 0.012*"nice" + 0.012*"love" + 0.011*"little"
# INFO:gensim.models.ldamodel:topic diff=0.003805, rho=0.080671
# INFO:gensim.models.ldamodel:-6.068 per-word bound, 67.1 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 148, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 148, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 148, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 148, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 148, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 148, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.083*"dress" + 0.023*"waist" + 0.023*"look" + 0.023*"fabric" + 0.015*"skirt" + 0.012*"length" + 0.011*"beautiful" + 0.010*"material" + 0.010*"flatter" + 0.010*"short"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.127*"size" + 0.054*"small" + 0.048*"order" + 0.031*"large" + 0.027*"medium" + 0.021*"true" + 0.017*"fit" + 0.016*"petite" + 0.014*"store" + 0.014*"retailer"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.042*"great" + 0.038*"dress" + 0.037*"wear" + 0.027*"jean" + 0.026*"perfect" + 0.022*"comfortable" + 0.022*"love" + 0.020*"color" + 0.017*"pant" + 0.015*"summer"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.034*"color" + 0.026*"shirt" + 0.024*"look" + 0.018*"sweater" + 0.017*"fabric" + 0.015*"soft" + 0.013*"white" + 0.012*"nice" + 0.012*"love" + 0.011*"little"
# INFO:gensim.models.ldamodel:topic diff=0.003765, rho=0.080410
# INFO:gensim.models.ldamodel:-6.068 per-word bound, 67.1 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 149, dispatched chunk #0 = documents up to #4000/22641, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 149, dispatched chunk #1 = documents up to #8000/22641, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 149, dispatched chunk #2 = documents up to #12000/22641, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 149, dispatched chunk #3 = documents up to #16000/22641, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 149, dispatched chunk #4 = documents up to #20000/22641, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 149, dispatched chunk #5 = documents up to #22641/22641, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.083*"dress" + 0.023*"waist" + 0.023*"look" + 0.023*"fabric" + 0.015*"skirt" + 0.012*"length" + 0.011*"beautiful" + 0.010*"material" + 0.010*"flatter" + 0.010*"short"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.127*"size" + 0.055*"small" + 0.048*"order" + 0.031*"large" + 0.027*"medium" + 0.021*"true" + 0.017*"fit" + 0.016*"petite" + 0.014*"store" + 0.014*"retailer"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.042*"great" + 0.038*"dress" + 0.037*"wear" + 0.027*"jean" + 0.026*"perfect" + 0.022*"comfortable" + 0.022*"love" + 0.020*"color" + 0.017*"pant" + 0.015*"summer"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.034*"color" + 0.026*"shirt" + 0.024*"look" + 0.018*"sweater" + 0.017*"fabric" + 0.015*"soft" + 0.013*"white" + 0.012*"nice" + 0.012*"love" + 0.011*"little"
# INFO:gensim.models.ldamodel:topic diff=0.003714, rho=0.080151
# INFO:gensim.models.ldamodel:-6.068 per-word bound, 67.1 perplexity estimate based on a held-out corpus of 2641 documents with 42847 words
# INFO:gensim.utils:LdaMulticore lifecycle event {'msg': 'trained LdaModel(num_terms=1530, num_topics=4, decay=0.5, chunksize=4000) in 767.98s', 'datetime': '2021-11-05T09:47:06.032152', 'gensim': '4.1.2', 'python': '3.9.7 | packaged by conda-forge | (default, Sep 29 2021, 19:20:46) \n[GCC 9.4.0]', 'platform': 'Linux-4.15.0-159-generic-x86_64-with-glibc2.31', 'event': 'created'}
# time for 150  passes:  767.9923477172852  seconds

# %% [markdown]
# STEP 5: Here are your Topics!

# %%
ldamodel.show_topics(num_words=25, formatted=False)
# Out:
# [(0,
#   [('dress', 0.083370134),
#    ('waist', 0.02299345),
#    ('look', 0.022960795),
#    ('fabric', 0.022639794),
#    ('skirt', 0.014640253),
#    ('length', 0.012020286),
#    ('beautiful', 0.010689758),
#    ('material', 0.010224576),
#    ('flatter', 0.010110618),
#    ('short', 0.010081764),
#    ('little', 0.010009438),
#    ('nice', 0.008944226),
#    ('body', 0.0086883195),
#    ('work', 0.008556451),
#    ('shape', 0.008435519),
#    ('petite', 0.0084021995),
#    ('model', 0.008249083),
#    ('hip', 0.008227384),
#    ('bottom', 0.008093334),
#    ('color', 0.008057289),
#    ('much', 0.007919191),
#    ('line', 0.0074790856),
#    ('great', 0.0074631018),
#    ('right', 0.0073345983),
#    ('fit', 0.0073066726)]),
#  (1,
#   [('size', 0.12714909),
#    ('small', 0.054531682),
#    ('order', 0.047720738),
#    ('large', 0.031019436),
#    ('medium', 0.027167108),
#    ('true', 0.020845152),
#    ('fit', 0.01683209),
#    ('petite', 0.016092978),
#    ('store', 0.014172953),
#    ('retailer', 0.013511704),
#    ('wear', 0.01227326),
#    ('color', 0.011543423),
#    ('review', 0.011212039),
#    ('little', 0.011076654),
#    ('usual', 0.010931095),
#    ('regular', 0.010683843),
#    ('purchase', 0.009083123),
#    ('online', 0.008962851),
#    ('love', 0.008639415),
#    ('cute', 0.00852984),
#    ('great', 0.007762373),
#    ('beautiful', 0.0074185147),
#    ('length', 0.0073945927),
#    ('shoulder', 0.007387873),
#    ('top', 0.007156225)]),
#  (2,
#   [('great', 0.041565333),
#    ('dress', 0.03815234),
#    ('wear', 0.037147906),
#    ('jean', 0.027428426),
#    ('perfect', 0.02591749),
#    ('comfortable', 0.022479389),
#    ('love', 0.021638772),
#    ('color', 0.02006655),
#    ('pant', 0.016982866),
#    ('summer', 0.014952966),
#    ('soft', 0.014828242),
#    ('pair', 0.014055422),
#    ('look', 0.013631723),
#    ('compliment', 0.011484808),
#    ('work', 0.011270716),
#    ('fall', 0.009913522),
#    ('many', 0.0095445225),
#    ('casual', 0.009350149),
#    ('purchase', 0.009246296),
#    ('jacket', 0.009198933),
#    ('cute', 0.008670896),
#    ('time', 0.008512733),
#    ('black', 0.008099224),
#    ('skirt', 0.008098651),
#    ('super', 0.0080129225)]),
#  (3,
#   [('color', 0.034342967),
#    ('shirt', 0.026356611),
#    ('look', 0.02378037),
#    ('sweater', 0.01758677),
#    ('fabric', 0.01683914),
#    ('soft', 0.014624331),
#    ('white', 0.013064625),
#    ('nice', 0.012422663),
#    ('love', 0.011595804),
#    ('little', 0.011246121),
#    ('material', 0.010832807),
#    ('wear', 0.010542502),
#    ('cute', 0.010076074),
#    ('picture', 0.009902348),
#    ('great', 0.009708083),
#    ('blue', 0.00949797),
#    ('detail', 0.009298342),
#    ('wash', 0.009216043),
#    ('price', 0.008935503),
#    ('black', 0.008909584),
#    ('much', 0.007881352),
#    ('quality', 0.0077908374),
#    ('design', 0.007614704),
#    ('beautiful', 0.0073668435),
#    ('thin', 0.0070293043)])]
