# %% [markdown]
# ## Get started with Google Colab

# %% [markdown]
# 1. Go to google and search "Google colab"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Create new notebook

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Mount Google Colab to your Drive. In order to do so, you need to grant Google Colab access to your Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Once mounted, your can see a folder drive on the left

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. Create a new folder. This is where your course materials will be stored.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4. Go to https://github.com/chaklam-silpasuwanchai/Python-Data-Science-Training and copy the link.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5. Navigate to the folder you have just created. In my case it is "/content/drive/MyDrive/Python course"

# %%
# %cd "/content/drive/MyDrive/Python course"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 6. git clone (copy) the course materials to your Drive. Once successful, you can see course materials inside the folder you have created.

# %%
! git clone https://github.com/chaklam-silpasuwanchai/Python-Data-Science-Training.git

# %% [markdown]
# ![image.png](data:image/png;base64,...)
