# %% [markdown]
# ## Get started with Google Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/Thesis/Python-Data-Science-Training"
# Out:
# /content/drive/MyDrive/Thesis/Python-Data-Science-Training

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <center><img src="../figures/GoogleColab2.png" width=300 height=300 /></center>

# %% [markdown]
# <center><img src="../figures/GoogleColab3.png" width=300 height=300 /></center>

# %%
from IPython import display
display.Image("../figures/GoogleColab2.png")
